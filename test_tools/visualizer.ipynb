# %%
from tvb.simulator.lab import *
import tvb_data
import seaborn as sns
import time
import numpy as np
import pandas as pd
import os
import io

# %%
datapath = 'C:/Users/Wayne/Desktop/115/weights.txt'
scl = open(datapath,"r")
lines = scl.read()
tmp_d = pd.read_csv(io.StringIO(lines), sep='\t', header=None, index_col=None, engine="python")
sns.heatmap(tmp_d)
# Out:
# <AxesSubplot:>
